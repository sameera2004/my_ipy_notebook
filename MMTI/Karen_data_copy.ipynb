# %%
cd "/media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data"
# Out:
# /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data

# %%
from __future__ import print_function
import numpy as np
import sys, os, shutil

dir_path = "/media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans"
save_path = "/media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/data_39"

# %%
def copy_Karen_data(dir_data, d_data, file_start):
    mm = 1
    for k in os.listdir(dir_path):
        os.chdir(dir_path)
        if os.path.isdir(dir_path + "/" + k):
            if k.startswith("TM"):
                new_path = (dir_path + "/" + k + "/analysis_Inf/")
                os.chdir(k + "/analysis_Inf")
                # print ("data dir ", os.getcwd())
                for i in os.listdir(new_path):
                    if i.startswith("WHYHOWLOC"):
                        os.chdir(new_path +"/" +i)
                        print ("new ", os.getcwd())
                        for j in os.listdir(new_path + "/" + i):
                            if j.startswith(file_start):
                                    print (" mm and j", mm,  j)
                                    shutil.copyfile(j , d_data + "/" + str(mm) + "_" + j)
                                    mm += 1

# %%
copy_Karen_data(dir_path, save_path, "con_0005")
# Out:
# new  /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S01869/analysis_Inf/WHYHOWLOC_2x2_Pmodby_Duration_Errors_WLS_100s_20170421_1228pa
#  mm and j 1 con_0005.nii
# new  /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S01929/analysis_Inf/WHYHOWLOC_2x2_Pmodby_Duration_Errors_WLS_100s_20180322_1203pm
#  mm and j 2 con_0005.nii
# new  /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S02341/analysis_Inf/WHYHOWLOC_2x2_Pmodby_Duration_Errors_WLS_100s_20170421_1228pa
#  mm and j 3 con_0005.nii
# new  /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S02344/analysis_Inf/WHYHOWLOC_2x2_Pmodby_Duration_Errors_WLS_100s_20170421_1228pa
#  mm and j 4 con_0005.nii
# new  /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S02382/analysis_Inf/WHYHOWLOC_2x2_Pmodby_Duration_Errors_WLS_100s_20170421_1228pa
# ...

# %%
mm = 1
for k in os.listdir(dir_path):
    os.chdir(dir_path)
    # print ("last", os.getcwd())
    if os.path.isdir(dir_path + "/" + k):
        if k.startswith("TM"):
             new_path = (dir_path + "/" + k + "/analysis_Inf/")
             os.chdir(k + "/analysis_Inf")
             # print ("data dir ", os.getcwd())
             for i in os.listdir(new_path):
                   if i.startswith("WHYHOWLOC"):
                         os.chdir(new_path +"/" +i)
                         print ("new ", os.getcwd())
                         for j in os.listdir(new_path + "/" + i):
                             #print (j)
                             if j.startswith("con_0005"):
                                    print ("j", j)
                               
    #os.chdir(dir_path)
    #print ("last", os.getcwd())
                                 #pwd
                         		 #print (j)
# Out:
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# last /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans
# ...

# %%
cd analysis_Inf/
# Out:
# /media/sameera/Back_Up_Book_jvans/Sameera/Scott's_work/Karen_data/WhyHow_Scans/TMII_XNAT_S01869/analysis_Inf
