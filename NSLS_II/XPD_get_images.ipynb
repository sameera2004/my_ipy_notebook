# %%
import dataportal

# %%
# !host_name
# Out:
# /bin/sh: 1: host_name: not found

# %%
from dataportal import DataBroker as db
from dataportal import get_images, get_events
from dataportal.broker import DataBroker as db, get_events, get_table, get_images

# %%
hdr= db[-21]

# %%
print(hdr)
# Out:
# header
# ...
#
#   EventDescriptor
#   ---------------
#   +----------------------+--------+------------+--------------+-------------------------------------------------+
#   | data keys            | dtype  |  external  |    shape     |                      source                     |
#   +----------------------+--------+------------+--------------+-------------------------------------------------+
#   | pe1_acquire_period   | number |            |      []      | PV:XF:28IDC-ES:1{Det:PE1}cam1:AcquirePeriod_RBV |
#   | pe1_acquire_time     | number |            |      []      |  PV:XF:28IDC-ES:1{Det:PE1}cam1:AcquireTime_RBV  |
#   | pe1_image_lightfield | array  | FILESTORE: | [2048, 2048] |            PV:XF:28IDC-ES:1{Det:PE1}            |
#   | shctl1               | number |            |      []      |    PV:XF:28IDC-ES:1{Det:PE1}cam1:ShutterMode    |
#   +----------------------+--------+------------+--------------+-------------------------------------------------+
# ...

# %%
imgs = get_images(hdr, 'pe1_image_lightfield')
imgs
# Out:
# <Frames>
# Length: 2 frames
# Frame Shape: 2048 x 2048
# Pixel Datatype: float32

# %%
imgs[0]
# Out:
# Frame([[    0.,     0.,     0., ...,     0.,     0.,     0.],
#        [ 4748.,  4707.,  4748., ...,  4149.,  4189.,  4108.],
#        [ 4756.,  4765.,  4775., ...,  4355.,  4246.,  4239.],
#        ...,
#        [ 4374.,  4438.,  4426., ...,  4603.,  4589.,  4639.],
#        [ 4310.,  4359.,  4368., ...,  4508.,  4571.,  4591.],
#        [    0.,     0.,     0., ...,     0.,     0.,     0.]], dtype=float32)

# %%
events = get_events(hdr)

# %%
events
# Out:
# <generator object get_events at 0x7f03fda21708>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots()
im = ax.imshow(imgs[0],vmin=0, vmax=40000, cmap='viridis')
#ax.set_title( ')
plt.colorbar( im  )
plt.show()

# %%
hdr= db[-78]
imgs = get_images(hdr, 'pe1_image_lightfield')
imgs
# Out:
# <Frames>
# Length: 10 frames
# Frame Shape: 2048 x 2048
# Pixel Datatype: float32

# %%
imgs[4]
# Out:
# Frame([[    0.,     0.,     0., ...,     0.,     0.,     0.],
#        [ 4797.,  4807.,  4794., ...,  4182.,  4277.,  4146.],
#        [ 4871.,  4775.,  4812., ...,  4442.,  4309.,  4280.],
#        ...,
#        [ 4492.,  4507.,  4522., ...,  4661.,  4677.,  4720.],
#        [ 4391.,  4418.,  4404., ...,  4568.,  4628.,  4650.],
#        [    0.,     0.,     0., ...,     0.,     0.,     0.]], dtype=float32)
