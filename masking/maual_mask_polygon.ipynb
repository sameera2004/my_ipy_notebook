# %%
from xray_vision.mask.manual_mask import ManualMask as m_mask
import numpy as np
#y = np.load('/mnt/hgfs/Data/ipython_NoteBooks/my_ipy_notebook/masking/avg_img.npy')
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib notebook

# %%
y = np.random.random((20,20))

# %%
m = m_mask(y)
plt.show(0)
# Out:
# <img src="data:image/png;base64,...">

# %%
ty= m.mask
plt.figure()
plt.imshow(ty)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %run download.py
# Out:
# __file__
# current_folder = /Volumes/Data/ipython_NoteBooks/my_ipy_notebook/masking
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /Users/sameera/mc/envs/py3k/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#
# /Users/sameera/mc/envs/py3k/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# ...

# %%
data_dir = "Duke_data/"
duke_rdata = np.load(data_dir+"duke_img_1_5000.npy")
duke_dark = np.load(data_dir+"duke_dark.npy")

duke_data = []
for i in range(duke_rdata.shape[0]):
    duke_data.append(duke_rdata[i] - duke_dark)
    
duke_ndata=np.asarray(duke_data)

# %%
y = np.save("avg_img", avg_img)

# %%
pwd
# Out:
# u'/mnt/hgfs/Data/ipython_NoteBooks/my_ipy_notebook/masking'

# %%
#  get the average image
avg_img = np.average(duke_data, axis=0)



# if matplotlib version 1.5 or later
if float('.'.join(mpl.__version__.split('.')[:2])) >= 1.5:
    cmap = 'viridis'
else:
    cmap = 'Dark2'

# plot the average image data after masking
plt.figure()
plt.imshow(avg_img, vmax=1e0, cmap= cmap )
plt.title("Averaged masked data for Duke Silica Gel ")
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
f, axarr = plt.subplots(1, 2,  figsize=(10, 8))
axarr[0].imshow(avg_img, vmax=1e0, cmap="viridis")
axarr[0].set_title("image")
m = m_mask(avg_img, vmax=1e0, cmap='viridis')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
ma = m.mask

fig, ax = plt.subplots()
ax.imshow(ma)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
